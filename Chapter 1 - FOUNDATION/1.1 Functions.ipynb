# %% [markdown]
# # Code caveat #1 : Numpy

# %%
print("Python list operation :")
# Out:
# Python list operation :

# %%
a = [1,2,3]
b = [4,5,6]

# %%
print("a+b :", a+b )
# Out:
# a+b : [1, 2, 3, 4, 5, 6]

# %%
# python list operations

try:
    print(a*b)
except TypeError :
    print("a*b has no meaning for python lists")
print()
# Out:
# a*b has no meaning for python lists

# %%
# umpy array operations

import numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])
print("a+b:", a+b )
print("a*b:", a*b )
# Out:
# a+b: [5 7 9]
# a*b: [ 4 10 18]

# %% [markdown]
# ## Axes in ndArray
# Axes are defined for arrays with more than one dimension. A 2-dimensional array has two corresponding axes: the first running vertically downwards across rows (axis 0), and the second running horizontally across columns (axis 1).

# %% [markdown]
# ![array.jpg](attachment:array.jpg)

# %%
# provided with a 2D array

a = np.array([[1,2],[3,4]])

# %%
print("a:")
print(a)
print("a.sum(axis=0):" , a.sum(axis=0))
print("a.sum(axis=1):" , a.sum(axis=1))
# Out:
# a:
# [[1 2]
#  [3 4]]
# a.sum(axis=0): [4 6]
# a.sum(axis=1): [3 7]

# %%
a = np.array([[1,2,3],[4,5,6]])
b = np.array([10,20,30])
print("a+b:\n", a+b )
# Out:
# a+b:
#  [[11 22 33]
#  [14 25 36]]

# %% [markdown]
# # Code caveat #2 : Type-checked functions

# %%
def operation(x1 , x2):

# %%
# We will use type-checked functions throughout this journey

def operation(x1 : ndarray, x2 : ndarray) -> ndarray:

# %%
# Basic functions in Numpy

def square(x : ndarray) -> ndarray:
    
    #Square each element in the inout ndarray.
    return np.power(x,2)

def leaky_relu(x : ndarray) -> ndarray:
    
    #Apply "leaky Relu"function to each element in ndarray.
    
    return np.maximum(0.2 * x, x)
